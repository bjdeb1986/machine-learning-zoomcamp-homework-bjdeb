# %% [markdown]
# Vector Operations: In linear algerba vectors are columns

# %%
import numpy as np

# %%
u = np.array([2, 4, 5, 6])
u
# Out:
# array([2, 4, 5, 6])

# %%
v = np.array([1, 0, 0, 2])
v
# Out:
# array([1, 0, 0, 2])

# %%
u + v # element wise addition
# Out:
# array([3, 4, 5, 8])

# %%
u * v # element wise multiplication
# Out:
# array([ 2,  0,  0, 12])

# %% [markdown]
# Vector-Vector Multiplication (dot product) -> multiply each element of the array and then sum it up

# %%
u.shape
# Out:
# (4,)

# %%
u.shape[0]
# Out:
# 4

# %%
def vector_vector_multiplication(u, v):
    assert u.shape[0] == v.shape[0]
    n = u.shape[0]
    result = 0.0
    for i in range(n):
        result = result + u[i] * v[i]
    return result

# %%
vector_vector_multiplication(u, v)
# Out:
# np.float64(14.0)

# %%
u.dot(v) # numpy way
# Out:
# np.int64(14)

# %% [markdown]
# Matrix-vector Multiplication -> each row of U gets multiplied by v and number of columns in U should match element of v

# %%
U = np.array([
    [2, 4, 5, 6],
    [1, 2, 1, 2],
    [3, 1, 2, 1]
])

# %%
U.shape[1] # column shape or size
# Out:
# 4

# %%
def matrix_vector_multiplication(U, v):
    assert U.shape[1] == v.shape[0]
    num_rows = U.shape[0]
    result = np.zeros(num_rows)
    for i in range(num_rows):
        result[i] = vector_vector_multiplication(U[i], v)
    return result

# %%
matrix_vector_multiplication(U, v)
# Out:
# array([14.,  5.,  5.])

# %%
U.dot(v) # numpy way
# Out:
# array([14,  5,  5])

# %% [markdown]
# Matrix-Matrix Multiplication

# %%
V = np.array([
    [1, 1, 2],
    [0, 0.5, 1],
    [0, 2, 1],
    [2, 1, 0]
])

# %%
def matrix_matrix_multiplication(U, V):
    assert U.shape[1] == V.shape[0]
    num_rows = U.shape[0]
    num_cols = V.shape[1]
    result = np.zeros((num_rows, num_cols))
    for i in range(num_cols):
        vi = V[:, 1]
        Uvi = matrix_vector_multiplication(U, vi)
        result[:, i] = Uvi
    return result

# %%
matrix_matrix_multiplication(U, V)
# Out:
# array([[20. , 20. , 20. ],
#        [ 6. ,  6. ,  6. ],
#        [ 8.5,  8.5,  8.5]])

# %%
U.dot(V) # numpy way
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %% [markdown]
# Identity Matrix

# %%
I = np.eye(3) # diagonally all elements are 1
I
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
V.dot(I)
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %% [markdown]
# Inverse

# %%
Vs = V[[0, 1, 2]]
Vs
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ]])

# %%
Vs_inv = np.linalg.inv(Vs)
Vs_inv
# Out:
# array([[ 1.        , -2.        ,  0.        ],
#        [ 0.        , -0.66666667,  0.66666667],
#        [ 0.        ,  1.33333333, -0.33333333]])

# %%
Vs_inv.dot(Vs)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
