# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
n = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = int(n * 0.6)

# %%
n, n_val+n_test+n_train # ideally value should be same but since we are rounding to nearest interger so there will be a small difference
# Out:
# (11914, 11912)

# %%
n = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test
n, n_val+n_test+n_train
# Out:
# (11914, 11914)

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
# to get subset of data based on the counts we can use iloc
df_train = df.iloc[:n_train]
df_val = df.iloc[n_train:n_train+n_val]
df_test = df.iloc[n_train+n_val:]

# %%
idx = np.arange(n)
np.random.seed(2)
np.random.shuffle(idx)

# %%
idx
# Out:
# array([2735, 6720, 5878, ..., 6637, 2575, 7336], shape=(11914,))

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val]:]
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 719)

# %%
df_train.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([ 9.57574708,  9.887663  ,  9.89323518, ..., 10.45380308,
#        12.62248099, 10.54061978], shape=(7150,))

# %%
len(y_train)
# Out:
# 7150

# %%
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %% [markdown]
# # 08 Baseline Model for Car Price Prediction Project

# %%
def train_linear_regression(X, y):
     ones = np.ones(X.shape[0])
     X = np.column_stack([ones, X])

     XTX = X.T.dot(X) # transpose matrix
     XTX_inv = np.linalg.inv(XTX)
     w_full = XTX_inv.dot(X.T).dot(y)

     return w_full[0], w_full[1:]

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         148.0               4.0           33        24        1385
# 1         132.0               4.0           32        25        2031
# 2         148.0               4.0           37        28         640
# 3          90.0               4.0           18        16         873
# 4         385.0               8.0           21        15        5657
# ...         ...               ...          ...       ...         ...
# 7145      300.0               6.0           31        20        3916
# 7146      210.0               4.0           30        24         873
# 7147      285.0               6.0           22        17         549
# 7148      563.0              12.0           21        13          86
# 7149      200.0               4.0           31        22         873
#
# [7150 rows x 5 columns]

# %%
df_train[base].values
# Out:
# array([[ 148.,    4.,   33.,   24., 1385.],
#        [ 132.,    4.,   32.,   25., 2031.],
#        [ 148.,    4.,   37.,   28.,  640.],
#        ...,
#        [ 285.,    6.,   22.,   17.,  549.],
#        [ 563.,   12.,   21.,   13.,   86.],
#        [ 200.,    4.,   31.,   22.,  873.]], shape=(7150, 5))

# %%
X_train = df_train[base].values

# %%
X_train = df_train[base].fillna(0)

# %%
w0, w = train_linear_regression(X_train, y_train)

# %%
y_pred = w0 + X_train.dot(w)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# this line is required to make sure all the plots can be displayed in the notebook
# %matplotlib inline

# %%
sns.histplot(y_pred, color='red', bins=50)
sns.histplot(y_train, color='blue', bins=50)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # 09 Root Mean Squared Error (RMSE)

# %%
def rmse(y, y_pred):
    sqrt_err = (y - y_pred) ** 2
    mean_sqrt_err = sqrt_err.mean()
    return np.sqrt(mean_sqrt_err)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7554192603920132)

# %% [markdown]
# # 10 Computing RMSE on Validation Data

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']
X_train = df_train[base].fillna(0).values
w0, w = train_linear_regression(X_train, y_train)
y_pred = w0 + X_train.dot(w)

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.761653099130156)

# %% [markdown]
# # 11 Simple Feature Engineering

# %%
df_train.year.max()
# Out:
# np.int64(2017)

# %%
def prepare_X(df):
    df = df.copy()
    df['age'] = 2017 - df.year # a new column "age" will get added of type int64 to the copied dataframe
    features = base + ['age']
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)

# %%
X_train
# Out:
# array([[1.480e+02, 4.000e+00, 3.300e+01, 2.400e+01, 1.385e+03, 9.000e+00],
#        [1.320e+02, 4.000e+00, 3.200e+01, 2.500e+01, 2.031e+03, 5.000e+00],
#        [1.480e+02, 4.000e+00, 3.700e+01, 2.800e+01, 6.400e+02, 1.000e+00],
#        ...,
#        [2.850e+02, 6.000e+00, 2.200e+01, 1.700e+01, 5.490e+02, 2.000e+00],
#        [5.630e+02, 1.200e+01, 2.100e+01, 1.300e+01, 8.600e+01, 3.000e+00],
#        [2.000e+02, 4.000e+00, 3.100e+01, 2.200e+01, 8.730e+02, 0.000e+00]],
#       shape=(7150, 6))

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5172055461058299)

# %%
sns.histplot(y_pred, color='red', bins=50)
sns.histplot(y_val, color='blue', bins=50)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # 12 Categorical variables

# %% [markdown]
# Although number of doors is represented by float but it's actually a catagorical variables because car can be of 2-doors car, 3-doors car, 4-doors car and son on. so we have create different columns for each door type

# %%
for v in [2, 3, 4]:
    df_train['num_doors_%s' % v] = (df_train.number_of_doors == v).astype('int')

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year # a new column "age" will get added of type int64 to the copied dataframe
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
prepare_X(df_train)
# Out:
# array([[148.,   4.,  33., ...,   1.,   0.,   0.],
#        [132.,   4.,  32., ...,   0.,   0.,   1.],
#        [148.,   4.,  37., ...,   0.,   0.,   1.],
#        ...,
#        [285.,   6.,  22., ...,   0.,   0.,   1.],
#        [563.,  12.,  21., ...,   0.,   0.,   1.],
#        [200.,   4.,  31., ...,   0.,   0.,   1.]], shape=(7150, 9))

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.515799564150169)

# %%
df.make.value_counts().head()
# Out:
# make
# chevrolet     1123
# ford           881
# volkswagen     809
# toyota         746
# dodge          626
# Name: count, dtype: int64

# %%
makes = list(df.make.value_counts().head().index)
makes
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year # a new column "age" will get added of type int64 to the copied dataframe
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)
    
    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5076038849556795)

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# num_doors_2            int64
# num_doors_3            int64
# num_doors_4            int64
# dtype: object

# %%
catagories_variables = ['make', 'engine_fuel_type', 'transmission_type', 'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style']

# %%
catagories = {}

for c in catagories_variables:
    catagories[c] = list(df[c].value_counts().head().index)

# %%
catagories
# Out:
# {'make': ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge'],
#  'engine_fuel_type': ['regular_unleaded',
#   'premium_unleaded_(required)',
#   'premium_unleaded_(recommended)',
#   'flex-fuel_(unleaded/e85)',
#   'diesel'],
#  'transmission_type': ['automatic',
#   'manual',
#   'automated_manual',
#   'direct_drive',
#   'unknown'],
#  'driven_wheels': ['front_wheel_drive',
#   'rear_wheel_drive',
#   'all_wheel_drive',
#   'four_wheel_drive'],
#  'market_category': ['crossover',
#   'flex_fuel',
#   'luxury',
#   'luxury,performance',
#   'hatchback'],
#  'vehicle_size': ['compact', 'midsize', 'large'],
#  'vehicle_style': ['sedan',
#   '4dr_suv',
#   'coupe',
#   'convertible',
#   '4dr_hatchback']}

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year # a new column "age" will get added of type int64 to the copied dataframe
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    for c, values in catagories.items():
        for v in values:
            df['%s_%s' % (c, v)] = (df[c] == v).astype('int')
            features.append('%s_%s' % (c, v))

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(23.019020704791835)

# %%
w0, w
# Out:
# (np.float64(4011091003551887.0),
#  array([ 5.17477261e-02,  5.87434156e+00,  2.58988500e+00, -9.14739385e-01,
#          3.29434090e-03,  1.26747065e+00,  1.09365186e+03,  1.08197230e+03,
#          1.08519232e+03, -2.94630727e+00, -7.48076191e+00,  1.02357603e+01,
#         -8.56657044e-01, -2.27736086e+00,  1.84973907e+00, -3.51656880e+00,
#         -2.20958315e+00,  6.07018281e+00, -3.32427158e+01, -4.60060984e+15,
#         -4.60060984e+15, -4.60060984e+15, -4.60060984e+15, -4.60060984e+15,
#          5.89518839e+14,  5.89518839e+14,  5.89518839e+14,  5.89518839e+14,
#         -9.26775404e-01,  3.51631589e-01,  1.80584944e-01,  1.46169331e+00,
#         -1.67201746e+00, -3.59104780e+00, -6.16304692e+00, -5.45706022e+00,
#         -4.85492239e-02,  5.44797374e-02,  1.78241160e-01,  3.41906701e-01,
#         -1.64412078e-01]))

# %% [markdown]
# # Regularization

# %%
def train_linear_regression_reg(X, y, r=0.001):   # r stands for regularization
     ones = np.ones(X.shape[0])
     X = np.column_stack([ones, X])

     XTX = X.T.dot(X) # transpose matrix
     XTX = XTX + r * np.eye(XTX.shape[0])
    
     XTX_inv = np.linalg.inv(XTX)
     w_full = XTX_inv.dot(X.T).dot(y)

     return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.45652199012897743)

# %% [markdown]
# # Tuning the model

# %%
for r in [0.0, 0.00001, 0.0001, 0.001, 0.1, 1, 10]:
    X_train = prepare_X(df_train)
    w0, w = train_linear_regression_reg(X_train, y_train, r=r)
    
    X_val = prepare_X(df_val)
    y_pred = w0 + X_val.dot(w)
    score = rmse(y_val, y_pred)

    print(r, w0, score)
# Out:
# 0.0 4011091003551887.0 23.019020704791835
# 1e-05 6.178192055025445 0.45651702823445617
# 0.0001 6.317246071243372 0.4565170654323052
# 0.001 6.285636717989048 0.45651750867781377
# 0.1 6.1912087238544915 0.4565692763007501
# 1 5.634896668066369 0.45722043179930605
# 10 4.283980108968471 0.4701456932099909

# %%
r = 0.01
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=r)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
score = rmse(y_val, y_pred)
score
# Out:
# np.float64(0.45652199012897743)

# %% [markdown]
# # Using The Model

# %%
df_full_train = pd.concat([df_train, df_val])

# %%
df_full_train = df_full_train.reset_index(drop=True)
df_full_train
# Out:
#             make                    model  year             engine_fuel_type  \
# 0      chevrolet                   cobalt  2008             regular_unleaded
# 1         toyota                   matrix  2012             regular_unleaded
# 2         subaru                  impreza  2016             regular_unleaded
# 3     volkswagen                  vanagon  1991             regular_unleaded
# 4           ford                    f-150  2017     flex-fuel_(unleaded/e85)
# ...          ...                      ...   ...                          ...
# 9527       volvo                      v60  2015             regular_unleaded
# 9528    maserati  granturismo_convertible  2015  premium_unleaded_(required)
# 9529    cadillac          escalade_hybrid  2013             regular_unleaded
# 9530  mitsubishi                   lancer  2016             regular_unleaded
# 9531         kia                  sorento  2015             regular_unleaded
#
# ...

# %%
X_full_train = prepare_X(df_full_train)

# %%
X_full_train
# Out:
# array([[148.,   4.,  33., ...,   1.,   0.,   0.],
#        [132.,   4.,  32., ...,   0.,   0.,   1.],
#        [148.,   4.,  37., ...,   0.,   0.,   1.],
#        ...,
#        [332.,   8.,  23., ...,   0.,   0.,   0.],
#        [148.,   4.,  34., ...,   0.,   0.,   0.],
#        [290.,   6.,  25., ...,   0.,   0.,   0.]], shape=(9532, 41))

# %%
y_full_train = np.concatenate([y_train, y_val])

# %%
w0, w = train_linear_regression_reg(X_full_train, y_full_train, r=0.001)

# %%
w
# Out:
# array([ 1.52506332e-03,  1.18188703e-01, -6.66105494e-03, -5.33413785e-03,
#        -4.87603208e-05, -9.69091838e-02, -7.92620449e-01, -8.90861655e-01,
#        -6.35100382e-01, -4.14339224e-02,  1.75560743e-01, -5.78063598e-04,
#        -1.00563877e-01, -9.27549641e-02, -4.66859195e-01,  7.98658894e-02,
#        -3.16047745e-01, -5.51981714e-01, -7.89526802e-02,  1.09397462e+00,
#         9.18667079e-01,  1.14824449e+00,  2.65138017e+00,  5.08603719e-01,
#         1.62979575e+00,  1.53049981e+00,  1.61767854e+00,  1.54567793e+00,
#        -9.70559706e-02,  3.73062128e-02, -5.81767490e-02, -2.35940871e-02,
#        -1.19357192e-02,  2.18895260e+00,  2.07458270e+00,  2.05916686e+00,
#        -5.00802769e-02,  5.62184639e-02,  1.84794024e-01,  3.32646151e-01,
#        -1.58817038e-01])

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)
score = rmse(y_test, y_pred)
score
# Out:
# np.float64(0.4713005774009665)

# %%
car = df_test.iloc[20].to_dict() # will take a random car from test data to predict model
car
# Out:
# {'make': 'mitsubishi',
#  'model': 'vanwagon',
#  'year': 1990,
#  'engine_fuel_type': 'regular_unleaded',
#  'engine_hp': 107.0,
#  'engine_cylinders': 4.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'rear_wheel_drive',
#  'number_of_doors': 3.0,
#  'market_category': nan,
#  'vehicle_size': 'compact',
#  'vehicle_style': 'cargo_minivan',
#  'highway_mpg': 20,
#  'city_mpg': 18,
#  'popularity': 436}

# %%
df_small = pd.DataFrame([car])
df_small
# Out:
#          make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0  mitsubishi  vanwagon  1990  regular_unleaded      107.0               4.0
#
#   transmission_type     driven_wheels  number_of_doors  market_category  \
# 0         automatic  rear_wheel_drive              3.0              NaN
#
#   vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity
# 0      compact  cargo_minivan           20        18         436

# %%
X_small = prepare_X(df_small)

# %%
y_pred = w0 + X_small.dot(w)
y_pred
# Out:
# array([7.54743003])

# %%
np.expm1(y_pred)
# Out:
# array([1894.86414729])

# %%
np.expm1(y_test[20])
# Out:
# np.float64(2000.0)
